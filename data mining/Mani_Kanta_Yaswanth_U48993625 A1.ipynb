# %% [markdown]
# ## Step 1: Import a number of libraries that we expect to use

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Mani Kanta Yaswanth\Downloads\_W02\_W02

# %% [markdown]
# ## Step 2:  Define a hidden linear relationship/model

# %%
# create a 'hidden' simple linear model
b1 = 15  # slope for x
b0 = 20  # y intercept

# %% [markdown]
# ## Step 3: Create input (X) and output data (y) using the model

# %%
sample_size = 100

# %%
# create sample_size number of x values between 0 and 100
X = np.linspace(0, 100, sample_size)

# %%
x_mean = 0
x_stdev = 10
X = np.round(np.random.normal(x_mean, x_stdev, sample_size),2)

# %%
y = b0 + b1 * X

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Add some random noise to 'hide' the model

# %%
e_mean = 0      # this must be zero when adding noise; do you know why?
e_stdev = 1500
e = np.round(np.random.normal(e_mean, e_stdev, sample_size), 2) # round to two decimal places
y = y + e

# %% [markdown]
# ## Step 5: Explore the resulting synthesized data

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Create a pandas data frame from the data

# %%
df = pd.DataFrame({'input': X, 'target': y})
df.head(3)
# Out:
#    input   target
# 0  16.24  -407.09
# 1  -6.12  1764.96
# 2  -5.28   546.04

# %% [markdown]
# ## Step 7: Save the data frame contents to a csv

# %%
df.to_csv('./data/c02_dataset1.csv', index=False)

# %%
df = pd.read_csv('./data/c02_dataset1.csv')

df.head(3)
# Out:
#    input   target
# 0  16.24  -407.09
# 1  -6.12  1764.96
# 2  -5.28   546.04

# %%
X=df[['input']]
y=df[['target']]

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(X,y) # note the underscore. This is a convention to indicate that the output is not used.


# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X, lin_reg.predict(X), color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)

# %%
print(f"Y = {b0:.2f} + {b1:.2f}x")
print(f"R^2: {lin_reg.score(X, y):.3f}") 
# for more on fstrings see here...
# https://www.freecodecamp.org/news/python-f-strings-tutorial-how-to-use-f-strings-for-string-formatting/
# Out:
# Y = 240.52 + 29.32x
# R^2: 0.034

# %% [markdown]
# ## Summary

# %% [markdown]
# After changing the sample size from 1000 to 100, the output data is even more unclear when compared to previous models accuracy.
# also the data is scattered wider comaped to previous model.
